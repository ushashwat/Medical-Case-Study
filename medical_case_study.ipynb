# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
# Upload the required files
from google.colab import files
files.upload()

# %%
# Read and display the 'emails sent' file
df_emails = pd.read_excel('Emails sent.xlsx')

# Rename columns to match the other dataframe and add a full name column
df_emails.rename(columns={'name_first':'first_name', 'name_last':'last_name'}, inplace=True)
df_emails["full_name"] = df_emails["first_name"] + " " + df_emails["last_name"]
df_emails
# Out:
#      last_name  ...          full_name
# 0    ADELGLASS  ...  JEFFREY ADELGLASS
# 1     ADKINSON  ...        N. ADKINSON
# 2        ALLEN  ...         MARK ALLEN
# 3    AMSTERDAM  ...   DANIEL AMSTERDAM
# 4      AMSTUTZ  ...     HARLAN AMSTUTZ
# ..         ...  ...                ...
# 267      YADAV  ...       SANJAY YADAV
# 268     YANNEY  ...       JAMES YANNEY
# 269      ZHANG  ...       JINGWU ZHANG
# 270      ZIRAN  ...        BRUCE ZIRAN
# 271       ZOSA  ...          NOLI ZOSA
#
# [272 rows x 6 columns]

# %%
# Read and display the 'fines paid by doctors' file
df_fines = pd.read_csv('Fines paid  by doctors.csv')

# Add a full name column similar to the other file
df_fines["full_name"] = df_fines["first_name"] + " " + df_fines["last_name"]
df_fines
# Out:
#                       org_indiv first_name  ...  online_fine            full_name
# 0      3-D MEDICAL SERVICES LLC     STEVEN  ...         $-     STEVEN DEITELZWEIG
# 1              AA DOCTORS, INC.     AAKASH  ...         $-           AAKASH AHUJA
# 2        ABBO, LILIAN MARGARITA     LILIAN  ...      $448.00          LILIAN ABBO
# 3        ABBO, LILIAN MARGARITA     LILIAN  ...      $119.00          LILIAN ABBO
# 4        ABBO, LILIAN MARGARITA     LILIAN  ...         $-            LILIAN ABBO
# ...                         ...        ...  ...           ...                 ...
# 10082    ZUWALLACK, RICHARD LEO    RICHARD  ...         $-      RICHARD ZUWALLACK
# 10083    ZUWALLACK, RICHARD LEO    RICHARD  ...       $65.00    RICHARD ZUWALLACK
# 10084           ZUZARTE, EDWARD     EDWARD  ...       $61.00       EDWARD ZUZARTE
# 10085           ZUZARTE, EDWARD     EDWARD  ...         $-         EDWARD ZUZARTE
# 10086           ZUZARTE, EDWARD     EDWARD  ...       $28.00       EDWARD ZUZARTE
#
# [10087 rows x 9 columns]

# %% [markdown]
# # Standardise the mail_sent_date column values to YYYY-MM-DD standard date format

# %%
# Create a copy file to be used for further operations
df_emails2 = df_emails.copy()

# %%
df_emails2['mail_sent_date'] = pd.to_datetime(df_emails2['mail_sent_date']).dt.date
df_emails2
# Out:
#      last_name  ...          full_name
# 0    ADELGLASS  ...  JEFFREY ADELGLASS
# 1     ADKINSON  ...        N. ADKINSON
# 2        ALLEN  ...         MARK ALLEN
# 3    AMSTERDAM  ...   DANIEL AMSTERDAM
# 4      AMSTUTZ  ...     HARLAN AMSTUTZ
# ..         ...  ...                ...
# 267      YADAV  ...       SANJAY YADAV
# 268     YANNEY  ...       JAMES YANNEY
# 269      ZHANG  ...       JINGWU ZHANG
# 270      ZIRAN  ...        BRUCE ZIRAN
# 271       ZOSA  ...          NOLI ZOSA
#
# [272 rows x 6 columns]

# %% [markdown]
# # The year in which maximum number of emails were sent to doctors

# %%
pd.DataFrame(df_emails2.groupby(df_emails2['mail_sent_date'].apply(lambda x: x.year)).size().sort_values(ascending=False), columns=['emails'])
# Out:
#                 emails
# mail_sent_date
# 2014                32
# 2015                31
# 2019                25
# 2016                25
# 2010                25
# 2018                23
# 2013                21
# 2011                20
# 2012                16
# 2007                15
# 2009                14
# 2017                11
# 2008                 8
# 2020                 5
# 2006                 1

# %% [markdown]
# # Total fine paid per Office

# %%
# Create a copy file to be used for further operations
df_fines2 = df_fines.copy()

# %% [markdown]
# **Data Cleaning**

# %%
# Clean the first_name and last_name columns by only considering alphabets
df_fines2['first_name'] = np.where(df_fines2['first_name'].str.count(r'[^a-zA-Z]') > 0, "", df_fines2['first_name'])
df_fines2['last_name'] = np.where(df_fines2['last_name'].str.count(r'[^a-zA-Z]') > 0, "", df_fines2['last_name'])

# Clean the cash_fine and online_fine columns by removing special symbols other than period and then convert the values to float
df_fines2[' cash_fine '] = df_fines2[' cash_fine '].str.replace(r'[^0-9.]', '')
df_fines2[' cash_fine '] = pd.to_numeric(df_fines2[' cash_fine '].astype(str).str[:-3])

df_fines2[' online_fine '] = df_fines2[' online_fine '].str.replace(r'[^0-9.]', '')
df_fines2[' online_fine '] = pd.to_numeric(df_fines2[' online_fine '].astype(str).str[:-3])
df_fines2
# Out:
#                       org_indiv first_name  ...  online_fine            full_name
# 0      3-D MEDICAL SERVICES LLC     STEVEN  ...           NaN  STEVEN DEITELZWEIG
# 1              AA DOCTORS, INC.     AAKASH  ...           NaN        AAKASH AHUJA
# 2        ABBO, LILIAN MARGARITA     LILIAN  ...         448.0         LILIAN ABBO
# 3        ABBO, LILIAN MARGARITA     LILIAN  ...         119.0         LILIAN ABBO
# 4        ABBO, LILIAN MARGARITA     LILIAN  ...           NaN         LILIAN ABBO
# ...                         ...        ...  ...           ...                 ...
# 10082    ZUWALLACK, RICHARD LEO    RICHARD  ...           NaN   RICHARD ZUWALLACK
# 10083    ZUWALLACK, RICHARD LEO    RICHARD  ...          65.0   RICHARD ZUWALLACK
# 10084           ZUZARTE, EDWARD     EDWARD  ...          61.0      EDWARD ZUZARTE
# 10085           ZUZARTE, EDWARD     EDWARD  ...           NaN      EDWARD ZUZARTE
# 10086           ZUZARTE, EDWARD     EDWARD  ...          28.0      EDWARD ZUZARTE
#
# [10087 rows x 9 columns]

# %%
# Create a copy here to be used for getting the 'top 5 average fine paid per state and category' at the end of this notebook
df_fines_last = df_fines2.copy()

# %%
# Perform groupby operation for the following columns and add a total fine column
df_fines2 = df_fines2.groupby(['org_indiv','first_name','last_name','full_name','state'], as_index=False).sum()
df_fines2['total_fine'] = df_fines2.apply(lambda x: x[' cash_fine '] + x[' online_fine '], axis=1)
df_fines2
# Out:
#                      org_indiv first_name  ...  online_fine  total_fine
# 0     3-D MEDICAL SERVICES LLC     STEVEN  ...           0.0     2625.0
# 1             AA DOCTORS, INC.     AAKASH  ...           0.0     1000.0
# 2       ABBO, LILIAN MARGARITA     LILIAN  ...         567.0     2367.0
# 3        ABDULLAH RAFFEE MD PC   ABDULLAH  ...           0.0      750.0
# 4              ABEBE, SHEILA Y     SHEILA  ...          47.0      872.0
# ...                        ...        ...  ...           ...        ...
# 4712        ZUB, DAVID WILLIAM      DAVID  ...        1236.0     1283.0
# 4713           ZUBAL, BETH ANN       BETH  ...         562.0     2662.0
# 4714      ZUSMAN, RANDALL MARK    RANDALL  ...         500.0      500.0
# 4715    ZUWALLACK, RICHARD LEO    RICHARD  ...          65.0     1815.0
# 4716           ZUZARTE, EDWARD     EDWARD  ...          89.0     2089.0
#
# [4717 rows x 8 columns]

# %%
# Create multiple copies to be used for other operations
df_fines3 = df_fines2.copy()
df_fines4 = df_fines2.copy()
df_fines5 = df_fines2.copy()

df_emails3 = df_emails2.copy()

# %%
# Drop columns not needed for analysis
df_fines3.drop(['org_indiv','first_name','last_name',' cash_fine ',' online_fine '], axis=1, inplace=True)
df_emails3.drop(['last_name','first_name','name_middle','mail_sent_date'], axis=1, inplace=True)

# %%
# Marge the 'df_fines3' & 'df_emails3' dataframes
df_merge = pd.merge(df_fines3, df_emails3, on='full_name')
df_merge
# Out:
#           full_name  ...                                        office
# 0     ALAN RAPOPORT  ...       Center for Drug Evaluation and Research
# 1   RONALD BUKOWSKI  ...       Center for Drug Evaluation and Research
# 2   RONALD BUKOWSKI  ...       Center for Drug Evaluation and Research
# 3      THOMAS GAZDA  ...       Center for Drug Evaluation and Research
# 4      THOMAS GAZDA  ...       Center for Drug Evaluation and Research
# 5  JEFFREY LEVENSON  ...       Center for Drug Evaluation and Research
# 6      ROBERT RITCH  ...    Center for Devices and Radiological Health
# 7      ROBERT RITCH  ...    Center for Devices and Radiological Health
# 8        ADAM SMITH  ...    Center for Devices and Radiological Health
# 9      DOUGLAS WARD  ...  Center for Biologics Evaluation and Research
#
# [10 rows x 4 columns]

# %%
# Print the total fine paid per office
df_merge.groupby(['office'], as_index=False).sum()
# Out:
#                                          office  total_fine
# 0  Center for Biologics Evaluation and Research      2896.0
# 1    Center for Devices and Radiological Health     31309.0
# 2       Center for Drug Evaluation and Research    103767.0

# %% [markdown]
# # Get the highest total fine and lowest total fine paid per state

# %%
df_fines3.drop(['full_name'], axis=1, inplace=True)

# %% [markdown]
# **Highest total fine paid per state**

# %%
df_fines3.groupby(['state'], as_index=False).max()
# Out:
#    state  total_fine
# 0     AK      1750.0
# 1     AL     66096.0
# 2     AR     10504.0
# 3     AZ    103104.0
# 4     CA    252745.0
# 5     CO     53051.0
# 6     CT     90000.0
# 7     DC    101828.0
# 8     DE     22795.0
# 9     FL   1185466.0
# 10    GA     51659.0
# 11    HI      8031.0
# 12    IA    123375.0
# 13    ID     10310.0
# 14    IL     90000.0
# 15    IN     52950.0
# 16    KS     70000.0
# 17    KY     60659.0
# 18    LA     43638.0
# 19    MA     93567.0
# 20    MD     54288.0
# 21    ME      6698.0
# 22    MI    152466.0
# 23    MN     94990.0
# 24    MO     86488.0
# 25    MS      8882.0
# 26    MT      5911.0
# 27    NC    156000.0
# 28    ND      4450.0
# 29    NE     14509.0
# 30    NH     89741.0
# 31    NJ     53686.0
# 32    NM     18750.0
# 33    NV     10890.0
# 34    NY    100096.0
# 35    OH     72425.0
# 36    OK      7762.0
# 37    OR     18527.0
# 38    PA    150778.0
# 39    PR     22283.0
# 40    RI     29356.0
# 41    SC     70041.0
# 42    SD      8297.0
# 43    TN    177786.0
# 44    TX    162900.0
# 45    UT     22213.0
# 46    VA     39709.0
# 47    VT     15587.0
# 48    WA     59020.0
# 49    WI     42122.0
# 50    WV     27259.0
# 51    WY      8066.0

# %% [markdown]
# **Lowest total fine paid per state**

# %%
df_fines3.groupby(['state'], as_index=False).min()
# Out:
#    state  total_fine
# 0     AK      1750.0
# 1     AL       588.0
# 2     AR       586.0
# 3     AZ       625.0
# 4     CA       502.0
# 5     CO       522.0
# 6     CT       551.0
# 7     DC       750.0
# 8     DE       562.0
# 9     FL        77.0
# 10    GA       500.0
# 11    HI       522.0
# 12    IA       687.0
# 13    ID      1435.0
# 14    IL       500.0
# 15    IN       500.0
# 16    KS       500.0
# 17    KY       500.0
# 18    LA       500.0
# 19    MA       500.0
# 20    MD       500.0
# 21    ME       710.0
# 22    MI       500.0
# 23    MN       682.0
# 24    MO       587.0
# 25    MS       554.0
# 26    MT      1404.0
# 27    NC         0.0
# 28    ND       750.0
# 29    NE       750.0
# 30    NH       721.0
# 31    NJ       500.0
# 32    NM      1060.0
# 33    NV       509.0
# 34    NY       500.0
# 35    OH       500.0
# 36    OK       578.0
# 37    OR       971.0
# 38    PA       500.0
# 39    PR       750.0
# 40    RI       560.0
# 41    SC       500.0
# 42    SD      1000.0
# 43    TN       500.0
# 44    TX       500.0
# 45    UT       500.0
# 46    VA       500.0
# 47    VT      1000.0
# 48    WA       500.0
# 49    WI       594.0
# 50    WV       584.0
# 51    WY       504.0

# %% [markdown]
# # The least 2 states that had to pay minimum 'online' fine

# %%
df_fines4.drop(['org_indiv','first_name','last_name','full_name',' cash_fine ','total_fine'], axis=1, inplace=True)

# %%
df_fines4 = df_fines4.groupby(['state'], as_index=False).sum()
df_fines4.sort_values(by=' online_fine ', ascending=True).head(2)
# Out:
#    state   online_fine
# 0     AK            0.0
# 28    ND          321.0

# %% [markdown]
# # The number of doctors that contributed to the state having highest 'cash' fine

# %%
df_fines5.drop(['org_indiv','first_name','last_name',' online_fine ','total_fine'], axis=1, inplace=True)

# %%
# Create a copy of the above file to later count the number of doctors for a particular state
df_fines5_doc = df_fines5.copy()

# %%
# Find the state having the highest cash fine
df_fines5 = df_fines5.groupby(['state'], as_index=False).sum()
df_fines5.sort_values(by=' cash_fine ', ascending=False).head(1)
# Out:
#   state   cash_fine
# 4    CA    3205893.0

# %%
# Count the numbers of doctors in that state having the highest cash fine by using the above copy file
df_fines5_doc['full_name'].loc[df_fines5_doc['state'] == 'CA'].count()
# Out:
# 554

# %% [markdown]
# # Get the top 5 average fine paid per state and category

# %%
# Treat the NaN values in both the fines columns and create a column for total fines
df_fines_last[' cash_fine '] = df_fines_last[' cash_fine '].fillna(0)
df_fines_last[' online_fine '] = df_fines_last[' online_fine '].fillna(0)
df_fines_last['total_fine'] = df_fines_last.apply(lambda x: x[' cash_fine '] + x[' online_fine '], axis=1)

# %% [markdown]
# **Top 5 average fine paid per state**

# %%
pd.DataFrame(df_fines_last.groupby('state')['total_fine'].nlargest(5))
# Out:
#             total_fine
# state
# AK    2364      1750.0
# AL    9256    232991.0
#       9257     66096.0
#       9255     55937.0
#       8576     46494.0
# ...                ...
# WY    9336      7750.0
#       4000      7425.0
#       5910      5200.0
#       7034      5125.0
#       1742      2625.0
#
# [256 rows x 1 columns]

# %% [markdown]
# **Top 5 average fine paid per category**

# %%
pd.DataFrame(df_fines_last.groupby('category')['total_fine'].nlargest(5))
# Out:
#                                                          total_fine
# category
# Business Related Travel                            5193     27681.0
#                                                    6975     21100.0
#                                                    6278     18573.0
#                                                    818      18063.0
#                                                    4564     14183.0
# Educational Items                                  2661       500.0
#                                                    4348       500.0
#                                                    7195       500.0
#                                                    1721        99.0
#                                                    2378        99.0
# Expert-Led Forums                                  7772    146500.0
#                                                    3798     79000.0
#                                                    5943     78000.0
#                                                    9600     75400.0
#                                                    6397     70500.0
# Infosys Sponsored Research initiated before Jul... 2331    857698.0
#                                                    9299    672263.0
#                                                    1966    617548.0
#                                                    9314    479314.0
#                                                    7340    323122.0
# Infosys Sponsored Research initiated on or afte... 6160   1185466.0
#                                                    7832    252745.0
#                                                    9113    177786.0
#                                                    2332    156000.0
#                                                    4223    152466.0
# Investigator-Initiated Research                    9311    162900.0
#                                                    9296    150778.0
#                                                    9312     94800.0
#                                                    9201     92000.0
#                                                    6455     90000.0
# Meals                                              1141      4189.0
#                                                    7773      4001.0
#                                                    7471      3796.0
#                                                    9601      3679.0
#                                                    3663      3071.0
# Professional Advising                              461     105000.0
#                                                    7955    100000.0
#                                                    5505     87610.0
#                                                    9751     85621.0
#                                                    8996     75609.0
